# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
class_survey_df = pd.read_csv('csci_1070_fall_23_survey.csv')
class_survey_df.head()
# Out:
#   What is your name? What state/country were you born in?  \
# 0              Kysen                             Illinois
# 1            Jameson                 Louisville, Kentucky
# 2         Aleksandre                   Country of Georgia
# 3            Ramedan                             Ethiopia
# 4                NaN               Illinois/United States
#
#   Are you working while in school?  \
# 0                               No
# 1                               No
# 2                               No
# 3                               No
# 4                               No
#
#   How much experience do you have programming? What class are you in?   \
# 0                                   0-3 months                Freshman
# 1                            6 months - 1 year                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have? How many pets and of which kind do you have?  \
# 0                              2              I have one dog, he is a maltese
# 1                              2                                       3 dogs
# 2                              1                               3 2-dogs 1-cat
# 3                              4                                            0
# 4                              1                                 I have 1 dog
#
#               What is your favorite type of food? Where do you live?  \
# 0                                       fast food          On campus
# 1                                 sushi or burger          On campus
# 2  Asian in general more specifaclly chinese food          On campus
# 3                                           Wings          On campus
# 4                                         Burgers          On campus
#
#   Do you take the metro? What is your major? How old are you?  \
# 0                     No    computer science               18
# 1                    Yes            comp sci               18
# 2                     No    Computer Science               17
# 3                     No    computer science               19
# 4                    Yes    Computer Science               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                  narcos mexico                         uncharted
# 1                         Naruto                Escape from Tarkov
# 2                 Don't have one         The Elder Scrolls: Skyrim
# 3                       The Wire                               NaN
# 4                       The Bear                            NHL 22
#
#                          What is your favorite book?  \
# 0                                 any dan brown book
# 1          Zen and the Art of Motorcycle Maintenance
# 2  Data Tutashkhia (Book about a person named Dat...
# 3                           In the end they both die
# 4                                                NaN
#
#   Whats your favorite bash command?
# 0                                cd
# 1                                ls
# 2                         git clone
# 3                               NaN
# 4                               N/a

# %%
class_survey_df['country'] = np.where(class_survey_df['What state/country were you born in?'] == 'Ethiopia', 'Ethiopia',
                                     np.where(class_survey_df['What state/country were you born in?'] == 'Nigeria', 'Nigeria',
                                             np.where(class_survey_df['What state/country were you born in?'] == 'Turkey', 'Turkey','USA')))
class_survey_df.head()
# Out:
#   What is your name? What state/country were you born in?  \
# 0              Kysen                             Illinois
# 1            Jameson                 Louisville, Kentucky
# 2         Aleksandre                   Country of Georgia
# 3            Ramedan                             Ethiopia
# 4                NaN               Illinois/United States
#
#   Are you working while in school?  \
# 0                               No
# 1                               No
# 2                               No
# 3                               No
# 4                               No
#
#   How much experience do you have programming? What class are you in?   \
# 0                                   0-3 months                Freshman
# 1                            6 months - 1 year                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have? How many pets and of which kind do you have?  \
# 0                              2              I have one dog, he is a maltese
# 1                              2                                       3 dogs
# 2                              1                               3 2-dogs 1-cat
# 3                              4                                            0
# 4                              1                                 I have 1 dog
#
#               What is your favorite type of food? Where do you live?  \
# 0                                       fast food          On campus
# 1                                 sushi or burger          On campus
# 2  Asian in general more specifaclly chinese food          On campus
# 3                                           Wings          On campus
# 4                                         Burgers          On campus
#
#   Do you take the metro? What is your major? How old are you?  \
# 0                     No    computer science               18
# 1                    Yes            comp sci               18
# 2                     No    Computer Science               17
# 3                     No    computer science               19
# 4                    Yes    Computer Science               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                  narcos mexico                         uncharted
# 1                         Naruto                Escape from Tarkov
# 2                 Don't have one         The Elder Scrolls: Skyrim
# 3                       The Wire                               NaN
# 4                       The Bear                            NHL 22
#
#                          What is your favorite book?  \
# 0                                 any dan brown book
# 1          Zen and the Art of Motorcycle Maintenance
# 2  Data Tutashkhia (Book about a person named Dat...
# 3                           In the end they both die
# 4                                                NaN
#
#   Whats your favorite bash command?   country
# 0                                cd       USA
# 1                                ls       USA
# 2                         git clone       USA
# 3                               NaN  Ethiopia
# 4                               N/a       USA

# %%
class_survey_df = class_survey_df.dropna(subset=['How many pets and of which kind do you have?'])
class_survey_df['How many pets and of which kind do you have?'].str.contains('none', '0')
class_survey_df['Dogs'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('dog'), '1','0')
class_survey_df['Cats'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('cat'), '1','0')
class_survey_df['Other_pets'] = np.where(class_survey_df['How many pets and of which kind do you have?'].str.contains('tutle'), '1','0')
class_survey_df.head()
# Out:
#   What is your name? What state/country were you born in?  \
# 0              Kysen                             Illinois
# 1            Jameson                 Louisville, Kentucky
# 2         Aleksandre                   Country of Georgia
# 3            Ramedan                             Ethiopia
# 4                NaN               Illinois/United States
#
#   Are you working while in school?  \
# 0                               No
# 1                               No
# 2                               No
# 3                               No
# 4                               No
#
#   How much experience do you have programming? What class are you in?   \
# 0                                   0-3 months                Freshman
# 1                            6 months - 1 year                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have? How many pets and of which kind do you have?  \
# 0                              2              I have one dog, he is a maltese
# 1                              2                                       3 dogs
# 2                              1                               3 2-dogs 1-cat
# 3                              4                                            0
# 4                              1                                 I have 1 dog
#
#               What is your favorite type of food? Where do you live?  \
# 0                                       fast food          On campus
# 1                                 sushi or burger          On campus
# 2  Asian in general more specifaclly chinese food          On campus
# 3                                           Wings          On campus
# 4                                         Burgers          On campus
#
#   Do you take the metro? What is your major? How old are you?  \
# 0                     No    computer science               18
# 1                    Yes            comp sci               18
# 2                     No    Computer Science               17
# 3                     No    computer science               19
# 4                    Yes    Computer Science               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                  narcos mexico                         uncharted
# 1                         Naruto                Escape from Tarkov
# 2                 Don't have one         The Elder Scrolls: Skyrim
# 3                       The Wire                               NaN
# 4                       The Bear                            NHL 22
#
#                          What is your favorite book?  \
# 0                                 any dan brown book
# 1          Zen and the Art of Motorcycle Maintenance
# 2  Data Tutashkhia (Book about a person named Dat...
# 3                           In the end they both die
# 4                                                NaN
#
#   Whats your favorite bash command?   country Dogs Cats Other_pets
# 0                                cd       USA    1    0          0
# 1                                ls       USA    1    0          0
# 2                         git clone       USA    1    1          0
# 3                               NaN  Ethiopia    0    0          0
# 4                               N/a       USA    1    0          0

# %%
class_survey_df = class_survey_df.dropna(subset=['What is your favorite type of food?'])
class_survey_df['What is your favorite type of food?']
cuisine = {'fast food' : 'American',
           'Sushi' : 'Japanese',
           'sushi' : 'Japanese',
           'Burgers' : 'American',
           'Wings' : 'American',
           'Salmon' : 'Global',
           'Korean bbq' :'Korean',
           'Turkish Food' : 'Turkish',
           'Persian Food' : 'Persian',
           'Meat' : 'Global',
           'Asian' : 'Asian',
           'My favorite type of food is chicken' : 'Global',
           'pasta' : 'Italian',
           'Nigerian Jollof' : 'Nigerian',
           'sushi or burger' : 'Japanese or American',
           'Asian in general more specifaclly chinese food' : 'Chinese',
           'Sushi/Asian Cuisine' : 'Japanese',
           'Japanese' : 'Japanese',
           'Mexican' : 'Mexican',
           'italian ' : 'Italian',
           '' : 'None'}
class_survey_df['Favorite Cuisine'] = class_survey_df['What is your favorite type of food?'].map(cuisine)    
class_survey_df.head()
# Out:
#   What is your name? What state/country were you born in?  \
# 0              Kysen                             Illinois
# 1            Jameson                 Louisville, Kentucky
# 2         Aleksandre                   Country of Georgia
# 3            Ramedan                             Ethiopia
# 4                NaN               Illinois/United States
#
#   Are you working while in school?  \
# 0                               No
# 1                               No
# 2                               No
# 3                               No
# 4                               No
#
#   How much experience do you have programming? What class are you in?   \
# 0                                   0-3 months                Freshman
# 1                            6 months - 1 year                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have? How many pets and of which kind do you have?  \
# 0                              2              I have one dog, he is a maltese
# 1                              2                                       3 dogs
# 2                              1                               3 2-dogs 1-cat
# 3                              4                                            0
# 4                              1                                 I have 1 dog
#
#               What is your favorite type of food? Where do you live?  \
# 0                                       fast food          On campus
# 1                                 sushi or burger          On campus
# 2  Asian in general more specifaclly chinese food          On campus
# 3                                           Wings          On campus
# 4                                         Burgers          On campus
#
#   Do you take the metro?  ... How old are you? What is your favorite TV show?  \
# 0                     No  ...               18                  narcos mexico
# 1                    Yes  ...               18                         Naruto
# 2                     No  ...               17                 Don't have one
# 3                     No  ...               19                       The Wire
# 4                    Yes  ...               18                       The Bear
#
#   What is your favorite video game?  \
# 0                         uncharted
# 1                Escape from Tarkov
# 2         The Elder Scrolls: Skyrim
# 3                               NaN
# 4                            NHL 22
#
#                          What is your favorite book?  \
# 0                                 any dan brown book
# 1          Zen and the Art of Motorcycle Maintenance
# 2  Data Tutashkhia (Book about a person named Dat...
# 3                           In the end they both die
# 4                                                NaN
#
#   Whats your favorite bash command?   country Dogs Cats Other_pets  \
# 0                                cd       USA    1    0          0
# 1                                ls       USA    1    0          0
# 2                         git clone       USA    1    1          0
# 3                               NaN  Ethiopia    0    0          0
# 4                               N/a       USA    1    0          0
#
#        Favorite Cuisine
# 0              American
# 1  Japanese or American
# 2               Chinese
# 3              American
# 4              American
#
# [5 rows x 21 columns]

# %%
Major = {'Computer Science' :'Computer Science', 
         'Computer Science ' :'Computer Science',
         'comp sci' : 'Computer Science',
         'computer science' : 'Computer Science',
         'Computer Science B.S.' : 'Computer Science',
         'Data Science B.S.' : 'Data Science',
         'Finance, Economics' : 'Finance and Economics',
         'Cybersecurity' : 'Cybersecurity'}

class_survey_df['Major'] = class_survey_df['What is your major?'].map(Major)
class_survey_df['Major']
# Out:
# 0          Computer Science
# 1          Computer Science
# 2          Computer Science
# 3          Computer Science
# 4          Computer Science
# 5          Computer Science
# 6          Computer Science
# 7             Cybersecurity
# 8          Computer Science
# 9              Data Science
# 10         Computer Science
# 11         Computer Science
# 12         Computer Science
# 13         Computer Science
# 14    Finance and Economics
# 15         Computer Science
# 16         Computer Science
# 17         Computer Science
# 18         Computer Science
# 19         Computer Science
# 20         Computer Science
# 22         Computer Science
# 23         Computer Science
# Name: Major, dtype: object

# %%
class_survey_df['How old are you?'] = class_survey_df['How old are you?'].str.replace('I am 18 years old', '18')
class_survey_df.head()
# Out:
#   What is your name? What state/country were you born in?  \
# 0              Kysen                             Illinois
# 1            Jameson                 Louisville, Kentucky
# 2         Aleksandre                   Country of Georgia
# 3            Ramedan                             Ethiopia
# 4                NaN               Illinois/United States
#
#   Are you working while in school?  \
# 0                               No
# 1                               No
# 2                               No
# 3                               No
# 4                               No
#
#   How much experience do you have programming? What class are you in?   \
# 0                                   0-3 months                Freshman
# 1                            6 months - 1 year                Freshman
# 2                                   0-3 months                Freshman
# 3                                   0-3 months                Freshman
# 4                                   0-3 months                Freshman
#
#   How many siblings do you have? How many pets and of which kind do you have?  \
# 0                              2              I have one dog, he is a maltese
# 1                              2                                       3 dogs
# 2                              1                               3 2-dogs 1-cat
# 3                              4                                            0
# 4                              1                                 I have 1 dog
#
#               What is your favorite type of food? Where do you live?  \
# 0                                       fast food          On campus
# 1                                 sushi or burger          On campus
# 2  Asian in general more specifaclly chinese food          On campus
# 3                                           Wings          On campus
# 4                                         Burgers          On campus
#
#   Do you take the metro? What is your major? How old are you?  \
# 0                     No    computer science               18
# 1                    Yes            comp sci               18
# 2                     No    Computer Science               17
# 3                     No    computer science               19
# 4                    Yes    Computer Science               18
#
#   What is your favorite TV show? What is your favorite video game?  \
# 0                  narcos mexico                         uncharted
# 1                         Naruto                Escape from Tarkov
# 2                 Don't have one         The Elder Scrolls: Skyrim
# 3                       The Wire                               NaN
# 4                       The Bear                            NHL 22
#
#                          What is your favorite book?  \
# 0                                 any dan brown book
# 1          Zen and the Art of Motorcycle Maintenance
# 2  Data Tutashkhia (Book about a person named Dat...
# 3                           In the end they both die
# 4                                                NaN
#
#   Whats your favorite bash command?   country      Favorite Cuisine  \
# 0                                cd       USA              American
# 1                                ls       USA  Japanese or American
# 2                         git clone       USA               Chinese
# 3                               NaN  Ethiopia              American
# 4                               N/a       USA              American
#
#               Major
# 0  Computer Science
# 1  Computer Science
# 2  Computer Science
# 3  Computer Science
# 4  Computer Science

# %%
plt.hist(class_survey_df['How old are you?'])
plt.xlabel('Age')
plt.ylabel('No. of students')
#Most students are 18
# Out:
# Text(0, 0.5, 'No. of students')

# %%
survey = class_survey_df.groupby('How many siblings do you have?').count()
survey.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(survey['country'],labels = survey['How many siblings do you have?'], autopct='%1.0f%%')
#nobody is the only child
# Out:
# ([<matplotlib.patches.Wedge at 0x2816c1510>,
#   <matplotlib.patches.Wedge at 0x28178ccd0>,
#   <matplotlib.patches.Wedge at 0x28178e450>,
#   <matplotlib.patches.Wedge at 0x28178fad0>,
#   <matplotlib.patches.Wedge at 0x28179d110>],
#  [Text(0.22380166258348247, 1.0769924864291622, '1'),
#   Text(-1.0592090493052229, -0.2967763296995337, '2'),
#   Text(0.07506648270767592, -1.0974356578742548, '3'),
#   Text(0.8532822972020213, -0.6941968894208915, '4'),
#   Text(1.059208965946565, -0.2967766272104473, '5+')],
#  [Text(0.12207363413644497, 0.5874504471431794, '43%'),
#   Text(-0.5777503905301214, -0.16187799801792746, '22%'),
#   Text(0.04094535420418686, -0.5986012679314116, '22%'),
#   Text(0.46542670756473886, -0.37865284877503175, '4%'),
#   Text(0.5777503450617627, -0.1618781602966076, '9%')])

# %%
plt.plot(class_survey_df['How old are you?'], class_survey_df['How much experience do you have programming?'], '.')
plt.xlabel('Age')
plt.ylabel('Programming Experience ')
# Out:
# Text(0, 0.5, 'Programming Experience ')

# %%
work = class_survey_df.groupby('Are you working while in school?').count()
work.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(work['country'],labels = work['Are you working while in school?'], autopct='%1.0f%%')
#most students dont work while in school
# Out:
# ([<matplotlib.patches.Wedge at 0x2817f2cd0>,
#   <matplotlib.patches.Wedge at 0x281845f10>],
#  [Text(-0.3683674890029374, 1.0364870443211873, 'No'),
#   Text(0.3683673919600155, -1.036487078810236, 'Yes')],
#  [Text(-0.20092772127432948, 0.5653565696297385, '61%'),
#   Text(0.2009276683418266, -0.5653565884419469, '39%')])

# %%
Food = class_survey_df.groupby('Favorite Cuisine').count()
Food.reset_index(inplace=True)
fig, ax = plt.subplots()
ax.pie(Food['country'],labels = Food['Favorite Cuisine'], autopct='%1.0f%%')
#japanese cuisine is the most popular
# Out:
# ([<matplotlib.patches.Wedge at 0x281f4d250>,
#   <matplotlib.patches.Wedge at 0x28227d190>,
#   <matplotlib.patches.Wedge at 0x282275bd0>,
#   <matplotlib.patches.Wedge at 0x282274390>,
#   <matplotlib.patches.Wedge at 0x282272c10>,
#   <matplotlib.patches.Wedge at 0x28226ea10>,
#   <matplotlib.patches.Wedge at 0x28226d350>,
#   <matplotlib.patches.Wedge at 0x28221d410>,
#   <matplotlib.patches.Wedge at 0x282272c90>,
#   <matplotlib.patches.Wedge at 0x28229ae10>,
#   <matplotlib.patches.Wedge at 0x2822bc5d0>,
#   <matplotlib.patches.Wedge at 0x2822bc450>],
#  [Text(1.0089324334399594, 0.43824119472377554, 'American'),
#   Text(0.6343483593564188, 0.8986668787608789, 'Asian'),
#   Text(0.368367573915492, 1.036487014143262, 'Chinese'),
#   Text(-0.22380161216582517, 1.0769924969060731, 'Global'),
#   Text(-0.939861339184653, 0.5715423546037781, 'Italian'),
#   Text(-0.8532824353172374, -0.6941967196545118, 'Japanese'),
#   Text(0.07506662398801925, -1.0974356482104275, 'Japanese or American'),
#   Text(0.3683675496547624, -1.0364870227655272, 'Korean'),
#   Text(0.6343483383216019, -0.8986668936088736, 'Mexican'),
#   Text(0.8532824109439662, -0.6941967496132869, 'Nigerian'),
#   Text(1.0089324283110717, -0.43824120653165943, 'Persian'),
#   Text(1.0897545402588844, -0.14978331677843074, 'Turkish')],
#  [Text(0.5503267818763414, 0.2390406516675139, '13%'),
#   Text(0.346008196012592, 0.4901819338695702, '4%'),
#   Text(0.20092776759026834, 0.565356553169052, '4%'),
#   Text(-0.12207360663590462, 0.587450452857858, '13%'),
#   Text(-0.5126516395552653, 0.31175037523842436, '13%'),
#   Text(-0.46542678290031125, -0.3786527561751882, '26%'),
#   Text(0.04094543126619231, -0.5986012626602332, '4%'),
#   Text(0.2009277543571431, -0.5653565578721056, '4%'),
#   Text(0.3460081845390555, -0.4901819419684764, '4%'),
#   Text(0.46542676960579965, -0.3786527725163383, '4%'),
#   Text(0.5503267790787663, -0.23904065810817782, '4%'),
#   Text(0.5944115674139369, -0.08169999097005312, '4%')])
